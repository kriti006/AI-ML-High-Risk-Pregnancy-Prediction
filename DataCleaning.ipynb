# %%
import pandas as pd
df=pd.read_csv('high_risk_pregnancy_realistic_2000 (1).csv')
df.head()
# Out:
#              timestamp    patient_id device_source     village  age_years  \
# 0  2026-01-01 08:55:00  HRP202600001    ANM Tablet    Nandgaon         35
# 1  2026-01-01 09:00:00  HRP202600002   ASHA Mobile  Lakshmipur         33
# 2  2026-01-01 09:17:00  HRP202600003   ASHA Mobile     Haripur         28
# 3  2026-01-01 09:57:00  HRP202600004   ASHA Mobile    Shivpuri         25
# 4  2026-01-01 10:06:00  HRP202600005     PHC Kiosk    Madanpur         27
#
#    gravida_G  para_P  live_child_L  abortion_A  death_D  ...  \
# 0          3       2             2           0        1  ...
# 1          5       0             0           0        0  ...
# 2          1       0             0           1        0  ...
# 3          2       0             0           0        0  ...
# 4          2       0             0           0        0  ...
#
#    body_temperature_F  heart_rate_bpm  hemoglobin_g_dL  hba1c_percent  \
# 0                99.4            85.3             10.6            7.2
# ...

# %%
df.shape
# Out:
# (2000, 24)
