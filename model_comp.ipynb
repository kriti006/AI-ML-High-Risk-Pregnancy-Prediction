# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
results = pd.DataFrame({
    'Model':     ['Random Forest', 'XGBoost', 'Logistic Regression','Decision Tree','SVM'],
    'Accuracy':  [0.79,   0.8045, 0.80 ,.67,.78],
    'ROC-AUC':   [0.6664, 0.6848, 0.6848,.5451,.6602],
    'Precision': [0.29,   0.39,   0.42,.22,.32],
    'Recall':    [0.16,   0.23,   0.36,.35,.22],
    'F1 Score':  [0.21,   0.29,   0.39 ,.27,.26]
})

print(results.to_string(index=False))
# Out:
#               Model  Accuracy  ROC-AUC  Precision  Recall  F1 Score
#       Random Forest    0.7900   0.6664       0.29    0.16      0.21
#             XGBoost    0.8045   0.6848       0.39    0.23      0.29
# Logistic Regression    0.8000   0.6848       0.42    0.36      0.39
#       Decision Tree    0.6700   0.5451       0.22    0.35      0.27
#                 SVM    0.7800   0.6602       0.32    0.22      0.26

# %%
results.set_index('Model').plot(kind='bar', figsize=(12, 6), colormap='Set2')
plt.title('Model Comparison - All Metrics')
plt.ylabel('Score')
plt.xticks(rotation=0)
plt.legend(loc='lower right')
plt.tight_layout()
plt.show()

# %%
best_model = results.loc[results['Recall'].idxmax(), 'Model']
best_recall = results['Recall'].max()
best_f1 = results.loc[results['F1 Score'].idxmax(), 'Model']

print("Best Model (Recall) :", best_model, "→", best_recall)
print("Best Model (F1 Score):", best_f1)
# Out:
# Best Model (Recall) : Logistic Regression → 0.36
# Best Model (F1 Score): Logistic Regression
